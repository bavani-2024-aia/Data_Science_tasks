# %%
import pandas as pd

# Corrected dictionary with values for Age
data = {'Name': ['Alice', 'Bob', 'Alice', 'David'],
        'Age':}

df = pd.DataFrame(data)

# Remove the duplicate row (Alice, 25)
df_cleaned = df.drop_duplicates()

print(df_cleaned)
# Out:
#   Cell In[3], line 4
#     data = {'Name': ['Alice', 'Bob', 'Alice', 'David'],'Age'}
#                                                            ^
# SyntaxError: ':' expected after dictionary key
