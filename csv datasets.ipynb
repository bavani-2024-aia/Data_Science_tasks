# %%
import pandas as pd

# 1. This creates a quick sample CSV file in your folder
with open('students.csv', 'w') as f:
    f.write("Name,Grade,Age\nBavani,A,21\nAlice,B,22\nBob,A,23")

# 2. THE CORE TASK: Read the CSV file using Pandas
df_csv = pd.read_csv('students.csv')

print("--- Imported CSV Data ---")
print(df_csv)
